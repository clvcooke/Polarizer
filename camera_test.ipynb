# %%
from pypylon import pylon
import cv2

# conecting to the first available camera
camera = pylon.InstantCamera(pylon.TlFactory.GetInstance().CreateFirstDevice())
camera.Open()
# loading in the configuration file
print("Reading file back to camera's node map...")
nodeFile = "NodeMap.pfs"
pylon.FeaturePersistence.Load(nodeFile, camera.GetNodeMap(), True)

# Grabing Continusely (video) with minimal delay
camera.StartGrabbing(pylon.GrabStrategy_LatestImageOnly) 
converter = pylon.ImageFormatConverter()

# converting to opencv bgr format
converter.OutputPixelFormat = pylon.PixelType_BGR8packed
converter.OutputBitAlignment = pylon.OutputBitAlignment_MsbAligned

while camera.IsGrabbing():
    grabResult = camera.RetrieveResult(5000, pylon.TimeoutHandling_ThrowException)

    if grabResult.GrabSucceeded():
        # Access the image data
        image = converter.Convert(grabResult)
        img = image.GetArray()
        cv2.namedWindow('title', cv2.WINDOW_NORMAL)
        cv2.imshow('title', img)
        k = cv2.waitKey(1)
        if k == 27:
            break
    grabResult.Release()
    
# Releasing the resource    
v
cv2.destroyAllWindows()
# Out:
# Reading file back to camera's node map...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-a8ea68b26b73> in <module>
#      27         cv2.namedWindow('title', cv2.WINDOW_NORMAL)
#      28         cv2.imshow('title', img)
# ---> 29         k = cv2.waitKey(1)
#      30         if k == 27:
#      31             break
#
# KeyboardInterrupt:

# %%
import cv2

# %%
cv2.imwrite()

# %%
Basler a2A3840-45ucBAS (40075263)
  Image Format Control                  
    Sensor Width                        	3860
    Sensor Height                       	2178
    Reverse X                           	0
    Reverse Y                           	0
    Max Width                           	3860
    Max Height                          	2178
    Width                               	3840
    Height                              	2160
    Offset X                            	0
    Offset Y                            	0
    Center X                            	<not readable>
    Center Y                            	<not readable>
    Pixel Format                        	YCbCr422_8
    Pixel Size                          	Bpp16
    Dynamic Range Min                   	0
    Dynamic Range Max                   	255
    Test Pattern                        	Off
  Acquisition Control                   
    Acquisition Stop Mode               	AbortExposure
    Sensor Shutter Mode                 	Rolling
    Exposure Time [us]                  	48837.0
    Exposure Auto                       	Continuous
    Exposure Mode                       	Timed
    Sensor Bit Depth Mode               	Auto
    Sensor Bit Depth                    	Bpp12
    Acquisition Frame Rate [Hz]         	1000000.0
    Enable Acquisition Frame Rate       	0
    Sensor Readout Time [us]            	19950.0
    Resulting Acquisition Frame Rate [Hz]	20.050
    Resulting Transfer Frame Rate [Hz]  	20.050
    Trigger Selector                    	FrameStart
    Trigger Mode                        	Off
    Trigger Source                      	Software
    Trigger Activation                  	<not available>
    Generate Software Trigger           	<not readable>
    Trigger Delay [us]                  	0.0
    Acquisition Burst Mode              	Standard
    Acquisition Burst Frame Count       	1
    Resulting Frame Burst Rate [Hz]     	20.039
    Acquisition Status Selector         	AcquisitionActive
    Acquisition Status                  	1
  Auto Function Control                 
    Auto Target Brightness              	0.300
    Auto Function Profile               	MinimizeGain
    Gain Lower Limit [dB]               	0.000
    Gain Upper Limit [dB]               	47.999
    Exposure Time Lower Limit [us]      	1.0
    Exposure Time Upper Limit [us]      	999999.0
    Auto Function ROI Control           
      ROI Selector                      	ROI1
      Width                             	3860
      Height                            	2178
      Offset X                          	0
      Offset Y                          	0
      Brightness                        	1
      White Balance                     	1
      Highlight ROI                     	0
  Analog Control                        
    Gain [dB]                           	0.000
    Gain Auto                           	Off
    Black Level [DN]                    	0.000
    Gamma                               	1.0000
    Digital Shift                       	0
    Color Space                         	sRgb
  Image Processing Control              
    Color Space                         	sRgb
    Light Source Preset                 	Daylight6500K
    Light Source Preset Feature Selector	WhiteBalance
    Light Source Preset Feature Enable  	1
    White Balance Control               
      Balance Ratio Selector            	Red
      Balance Ratio                     	1.0000
      Balance White Auto                	Continuous
    Color Transformation Control        
      Color Transformation Selector     	RGBtoRGB
      Color Transformation Enable       	0
      Color Transformation Value Selector	Gain00
      Color Transformation Value        	1.0000
    Color Adjustment Control            
      Color Adjustment Enable           	0
      Color Adjustment Selector         	Red
      Color Adjustment Hue              	0.000
      Color Adjustment Saturation       	1.000
    LUT Control                         
      LUT Enable                        	1
      LUT Index [DN]                    	0
      LUT Value [DN]                    	0
  Digital I/O Control                   
    Line Selector                       	Line1
    Line Format                         	OptoCoupled
    Line Inverter                       	0
    Line Mode                           	Input
    Input Filter Time [us]              	0.00
    Input Hold-Off Time [us]            	0.00
    Line Source                         	<not available>
    Line Status                         	0
    Line Overload Status                	0
    Line Status All                     	0x6
    User Output Selector                	UserOutput1
    User Output Value                   	0
    User Output Value All               	0
  Counter and Timer Control             
    Counter Control                     
      Counter Selector                  	Counter1
      Counter Event Source              	Off
      Counter Event Activation          	<not available>
      Counter Reset Source              	Off
      Counter Reset Activation          	<not available>
      Counter Trigger Source            	Off
      Counter Trigger Activation        	<not available>
      Counter Value                     	0
      Counter Duration                  	4294967295
      Counter Status                    	CounterCompleted
      Counter Reset                     	<not readable>
    Timer Control                       
      Timer Selector                    	Timer1
      Timer Trigger Source              	Off
      Timer Trigger Activation          	<not available>
      Timer Delay [us]                  	0.00
      Timer Duration [us]               	10.00
      Timer Trigger Arm Delay [us]      	0.00
      Timer Status                      	TimerIdle
      Timer Reset                       	<not readable>
  Software Signal Control               
    Software Signal Selector            	SoftwareSignal1
    Software Signal Pulse               	<not readable>
  User Set Control                      
    User Set Selector                   	Default
    User Set Load                       	<not available>
    User Set Save                       	<not available>
    User Set Default                    	Default
  User Defined Values                   
    User Defined Value Selector         	Value1
    User Defined Value                  	0
  Device Control                        
    Device Scan Type                    	Areascan
    Device Vendor Name                  	Basler
    Device Model Name                   	a2A3840-45ucBAS
    Device Family Name                  	ace 2
    Device Manufacturer Info            	none
    Device Version                      	108015-10
    Device Firmware Version             	p=vu3_imx334c_bas/s=r/v=1.0.0/i=4416.8/h=c6416d2
    Device Serial Number                	40075263
    Device User ID                      	
    Device Indicator Mode               	Active
    Device Link Throughput Limit Mode   	On
    Device Link Throughput Limit        	360000000
    Device Link Current Throughput      	332420896
    Device Temperature Selector         	Coreboard
    Device Temperature [C]              	56.5
    Temperature Status                  	Ok
    Temperature Status Error Count      	0
    Temperature Max [C]                 	59.4
    Timestamp Latch                     	<not readable>
    Timestamp Latch Value [ns]          	0
    Device Reset                        	<not readable>
    Device SFNC Version Major           	2
    Device SFNC Version Minor           	5
    Device SFNC Version SubMinor        	0
    Device Manifest XML Major Version   	1
    Device Manifest XML Minor Version   	0
    Device Manifest XML Sub Minor Version	0
    Device Manifest Schema Major Version	1
    Device Manifest Schema Minor Version	1
    Device TL Type                      	USB3Vision
    Device TL Version Major             	1
    Device TL Version Minor             	1
    Device TL Version Sub Minor         	0
    Device GenCP Version Major          	1
    Device GenCP Version Minor          	3
    Device Character Set                	UTF8
    Device Feature Persistence Start    	<not available>
    Device Feature Persistence End      	<not available>
    Start Feature Streaming             	<not available>
    Stop Feature Streaming              	<not available>
    Device Registers Endianness         	Little
  Test Control                          
    Test Pending Ack                    	0
  Transport Layer Control               
    Payload Size [B]                    	16588800
    USB Speed Mode                      	SuperSpeed
    Payload Transfer Size [B]           	1048576
    Payload Transfer Count              	15
    Payload Final Transfer1 Size [B]    	860160
    Payload Final Transfer2 Size [B]    	0
  Error Report Control                  
    Error Report Value                  	0
    Error Report Next                   	<not readable>
    Error Present                       	0
Stream Parameters
  Maximum Number of Buffers             	10
  Maximum Buffer Size                   	16588800
  Maximum Transfer Size                 	1048576
  Num Max Queued Urbs                   	64
  Transfer Loop Thread Priority         	15
  Statistic                             
    Total Buffer Count                  	897
    Failed Buffer Count                 	0
    Last Failed Buffer Status           	0
    Status code of the last failed buffer.	
    Missed Frame Count                  	0
    Resynchronization Count             	0
    Last Block Id                       	896
    Out Of Memory Error Count           	0
Host Transport Layer
  Migration Mode Enable                 	0
  Statistic                             
    Read Pipe Reset Count               	0
    Write Pipe Reset Count              	0
    Read Operations Failed Count        	0
    Write Operations Failed Count       	0
    Last Error Status                   	0
    Last Error Status Text              	
Event Grabber Parameters
  NumBuffer                             	20
  Num Max Queued Urbs                   	5
  Transfer Loop Thread Priority         	15
  Statistic                             
    Total Event Count                   	0
    Failed Event Count                  	0
    Last Failed Event Buffer Status     	0
Image Format Conversion
  Output Bit Alignment                  	MsbAligned
  Output Orientation                    	Unchanged
  Mono Conversion                       
    Mono Conversion Method              	Truncate
    Gamma                               	<not available>
    Additional Left Shift               	0

# %%
camera.
# Out:
# <pypylon.pylon.InstantCamera; proxy of <Swig Object of type 'Pylon::CInstantCamera *' at 0x000001F6C3FE87B0> >
